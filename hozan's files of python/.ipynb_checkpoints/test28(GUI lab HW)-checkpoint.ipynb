# %%
def insf():
    tx=e.get()
    lb.insert(END,tx)
    e.delete(0,END)

def delf():
    lb.delete(ANCHOR)

def getf():
    l.config(text=lb.get(ANCHOR))
    
def showall():
    l.config(text=lb.get(0,END))    

def deleteall():
    lb.delete(0,END)   

def leng():
    l.config(text=len(lb.get(ANCHOR)))
    
    
from tkinter import *
r=Tk()
r.geometry("400x400")

f1=Frame(r,bg="yellow")  
f1.pack(side="top",fill=X)

e=Entry(f1)
e.pack(side="left")

b1=Button(f1,text="length",command=leng,bg="black",fg="white")
b1.pack(side="left",padx=30)

f4=Frame(r,bg="pink")  
f4.pack(side="bottom",fill=X)

b2=Button(f4,text="Insert",command=insf,bg="black",fg="white")
b2.pack(side="left")

b3=Button(f4,text="Delete",command=delf,bg="black",fg="white")
b3.pack(side="left",padx=10)

b4=Button(f4,text="show",command=getf,bg="black",fg="white")
b4.pack(side="left",padx=10)

b5=Button(f4,text="show all",command=showall,bg="black",fg="white")
b5.pack(side="left",padx=10)

b6=Button(f4,text="delete all",command=deleteall,bg="black",fg="white")
b6.pack(side="left",padx=10)

f2=Frame(r,bg="red")  
f2.pack(side="left",fill=Y)
s=StringVar()
lb=Listbox(f2)
lb.pack()


f3=Frame(r,bg="orange")  
f3.pack(side="right",fill=Y)

l=Label(f3,bg="yellow")
l.pack()

r.mainloop()

# %%
#-------------------------------------------------
#HW1

# %%
def leng():
    l.config(text=len(lb.get(ANCHOR)))

def insf():
    tx=e.get()
    lb.insert(END,tx)
    e.delete(0,END)

def delf():
    lb.delete(ANCHOR)

def getf():
    l.config(text=lb.get(ANCHOR))
    
def showall():
    l.config(text=lb.get(0,END))    

def deleteall():
    lb.delete(0,END)   
    
    
from tkinter import *
r=Tk()
r.geometry("400x400")

f1=Frame(r)  
f1.pack(side="top",fill=X)

e=Entry(f1)
e.pack(side="left")

b1=Button(f1,text="length",command=leng,bg="black",fg="white")
b1.pack(side="left",padx=30)

f4=Frame(r)  
f4.pack(side="bottom",fill=X)

b2=Button(f4,text="Insert",command=insf,bg="black",fg="white")
b2.pack(side="left")

b3=Button(f4,text="Delete",command=delf,bg="black",fg="white")
b3.pack(side="left",padx=10)

b4=Button(f4,text="show",command=getf,bg="black",fg="white")
b4.pack(side="left",padx=10)

b5=Button(f4,text="show all",command=showall,bg="black",fg="white")
b5.pack(side="left",padx=10)

b6=Button(f4,text="delete all",command=deleteall,bg="black",fg="white")
b6.pack(side="left",padx=10)

f2=Frame(r)  
f2.pack(side="left",fill=Y)
#s=StringVar()
lb=Listbox(f2)
lb.pack(pady=30)

f3=Frame(r)  
f3.pack(side="right",fill=Y)

l=Label(f3,bg="yellow")
l.pack(pady=30,padx=30)

r.mainloop()

# %%
#-------------------------------------------------
#HW2

# %%
def insf():
    tx=e.get()
    lb1.insert(END,tx)
    e.delete(0,END)

def delf():
    lb1.delete(ANCHOR)

def sortlist():
    st=lb1.get(0,END)
    lb1.delete(0,END)
    for i in st:
        if(i[0].upper() <= 'E'):
            lb2.insert(END,i)
        else:
            lb3.insert(END,i)
    
    # print(st)   # values of st will be inside the tuple ==> ('txt1', 'txt2', 'txt3')
    
    
from tkinter import *
r=Tk()
r.geometry("400x500")

f=Frame(r)
f.pack(side="top",fill=X,padx=30)

e=Entry(f)
e.pack(side="left")

b=Button(f,text="Insert",bg="black",fg="white",command=insf)
b.pack(side="left",padx=30)

f1=Frame(r)
f1.pack(side="left",fill=Y,padx=30)


lb1=Listbox(f1)
lb1.pack(pady=100)

b1=Button(f1,text="Delete",bg="black",fg="white",command=delf)
b1.pack(side="left")

b2=Button(f1,text="Go",bg="black",fg="white",command=sortlist)
b2.pack(side="left",padx=20)

f2=Frame(r)
f2.pack(side="left",fill=Y)
  
lb2=Listbox(f2)
lb2.pack(pady=15)

lb3=Listbox(f2)
lb3.pack(pady=15)

r.mainloop()

# %%
s='a'
print(s.upper())
# Out:
# A
