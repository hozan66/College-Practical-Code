# %%
from tkinter import *
from tkinter import ttk
r=Tk()
r.geometry('500x500')

my_tree=ttk.Treeview(r)

#Define Our Columns
my_tree['columns']=("Name","ID","Favorite Pizza")

#Format Our Columns
my_tree.column("#0",width=0,stretch=NO)
my_tree.column("Name",anchor=W,width=120)
my_tree.column("ID",anchor=CENTER,width=80)
my_tree.column("Favorite Pizza",anchor=W,width=120)

#Create Headings
my_tree.heading("#0",text="",anchor=W)
my_tree.heading("Name",text="Name",anchor=W)
my_tree.heading("ID",text="ID",anchor=CENTER)
my_tree.heading("Favorite Pizza",text="Favorite Pizza",anchor=W)

#Add Data
my_tree.insert(parent='',index='end',iid=0,text="",values=("Jhon",1,"Peperroni Pizza"))
my_tree.insert(parent='',index='end',iid=1,text="",values=("Mas",2,"cheese Pizza"))
my_tree.insert(parent='',index='end',iid=2,text="",values=("Sed",3,"der Pizza"))
my_tree.insert(parent='',index='end',iid=3,text="",values=("Ali",4,"Ham Pizza"))
my_tree.insert(parent='',index='end',iid=4,text="",values=("Hoza",5,"deli Pizza"))
my_tree.insert(parent='',index='end',iid=5,text="",values=("Nor",6,"aprg Pizza"))

#Pack to the Screen
my_tree.pack(pady=20)

r.mainloop()

# %%
from tkinter import *
from tkinter import ttk
r=Tk()
r.geometry('500x500')

my_tree=ttk.Treeview(r)

#Define Our Columns
my_tree['columns']=("Name","ID","Favorite Pizza")

#Format Our Columns
my_tree.column("#0",width=0,stretch=NO)
my_tree.column("Name",anchor=W,width=120)
my_tree.column("ID",anchor=CENTER,width=80)
my_tree.column("Favorite Pizza",anchor=W,width=120)

#Create Headings
my_tree.heading("#0",text="",anchor=W)
my_tree.heading("Name",text="Name",anchor=W)
my_tree.heading("ID",text="ID",anchor=CENTER)
my_tree.heading("Favorite Pizza",text="Favorite Pizza",anchor=W)

#Add Data
data=[["Jhon",1,"Peperroni Pizza"],
       ["Mas",2,"cheese Pizza"],
        ["Sed",3,"der Pizza"],
        ["Ali",4,"Ham Pizza"],
        ["Hoza",5,"deli Pizza"],
        ["Nor",6,"aprg Pizza"]
      ]

count=0
for record in data:
    my_tree.insert(parent='',index='end',iid=count,text="",values=(record[0],record[1],record[2]))
    count+=1


#Pack to the Screen
my_tree.pack(pady=20)

r.mainloop()

# %%
#Bring the data from database

from tkinter import *
from tkinter import ttk
import pyodbc
r=Tk()
r.geometry('500x500')

my_tree=ttk.Treeview(r)

#Define Our Columns
my_tree['columns']=("Name","ID","Favorite Pizza")

#Format Our Columns
my_tree.column("#0",width=0,stretch=NO)
my_tree.column("Name",anchor=W,width=120)
my_tree.column("ID",anchor=CENTER,width=80)
my_tree.column("Favorite Pizza",anchor=W,width=120)

#Create Headings
my_tree.heading("#0",text="",anchor=W)
my_tree.heading("Name",text="Name",anchor=W)
my_tree.heading("ID",text="ID",anchor=CENTER)
my_tree.heading("Favorite Pizza",text="Favorite Pizza",anchor=W)

#Add Data
connection=pyodbc.connect('Driver={SQL Server};'  
                          'Server=HOZANPC;'
                          'Database=FoodCompany;'
                          'Trusted_Connection=yes;')

cursorObject=connection.cursor()

query=cursorObject.execute('select * from FoodCompany.dbo.emp')
#-----------------------------------------------------------------------

count=0
for record in query:
    my_tree.insert(parent='',index='end',iid=count,text="",values=(record[0],record[1],record[2]))
    count+=1


#Pack to the Screen
my_tree.pack(pady=20)

connection.commit() 
connection.close()

r.mainloop()

# %%
#Delete data from database with Treeview widget

#Bring the data from database

from tkinter import *
from tkinter import ttk
import pyodbc
r=Tk()
r.geometry('500x500')

my_tree=ttk.Treeview(r)

#Define Our Columns
my_tree['columns']=("Name","ID","Favorite Pizza")

#Format Our Columns
my_tree.column("#0",width=0,stretch=NO)
my_tree.column("Name",anchor=W,width=120)
my_tree.column("ID",anchor=CENTER,width=80)
my_tree.column("Favorite Pizza",anchor=W,width=120)

#Create Headings
my_tree.heading("#0",text="",anchor=W)
my_tree.heading("Name",text="Name",anchor=W)
my_tree.heading("ID",text="ID",anchor=CENTER)
my_tree.heading("Favorite Pizza",text="Favorite Pizza",anchor=W)

#Add Data
connection=pyodbc.connect('Driver={SQL Server};'  
                          'Server=HOZANPC;'
                          'Database=FoodCompany;'
                          'Trusted_Connection=yes;')

cursorObject=connection.cursor()
global query
query=cursorObject.execute('select * from FoodCompany.dbo.emp')
#-----------------------------------------------------------------------

# global count
count=0
for record in query:
    my_tree.insert(parent='',index='end',iid=count,text="",values=(record[0],record[1],record[2]))
    count+=1


#Pack to the Screen
my_tree.pack(pady=20)

def delete_record():
    
    selected=my_tree.focus()
    x=my_tree.selection()[0]  #my_tree.selection()[0] for select one item only
    
    #Getting the whole row
    row=my_tree.item(selected,'values')
#     print(row[0])
#     for j in row:
#         print(row)
#         print(j)

    my_tree.delete(x)
    
    #new connection with database
    connection=pyodbc.connect('Driver={SQL Server};'  
                          'Server=HOZANPC;'
                          'Database=FoodCompany;'
                          'Trusted_Connection=yes;')

    cursorObject=connection.cursor()
    
    cursorObject.execute("delete from FoodCompany.dbo.emp where Emp_Name=(?)",row[0])
    connection.commit() 
    connection.close()
#     query=cursorObject.execute('select * from FoodCompany.dbo.emp')
    
#     count=0
#     for record in query:
#         my_tree.insert(parent='',index='end',iid=count,text="",values=(record[0],record[1],record[2]))
#     count+=1
   
def add_record():
    global count
    n=name_box.get()
    y=int(id_box.get())
    z=topping_box.get()
    my_tree.insert(parent='',index='end',iid=count,text="",values=(name_box.get(),y,topping_box.get()))
    count+=1
    
    #Clear the Boxes
    name_box.delete(0,END)
    id_box.delete(0,END)
    topping_box.delete(0,END)
    
    #new connection with database
    connection=pyodbc.connect('Driver={SQL Server};'  
                          'Server=HOZANPC;'
                          'Database=FoodCompany;'
                          'Trusted_Connection=yes;')

    cursorObject=connection.cursor()
    
    cursorObject.execute("insert into FoodCompany.dbo.emp (Emp_Name,Emp_Salary,Emp_Dep) values(?,?,?)",
                         (n,y,z))
    connection.commit() 
    connection.close()
#     query=cursorObject

Button(r,text="delete",command=delete_record).pack(pady=20)

add_frame=Frame(r)
add_frame.pack(pady=20)

#Labels
nl=Label(add_frame,text="Name")
nl.grid(row=0,column=0)

il=Label(add_frame,text="ID")
il.grid(row=0,column=1)

tl=Label(add_frame,text="Topping")
tl.grid(row=0,column=2)

#Entry boxes
name_box=Entry(add_frame)
name_box.grid(row=1,column=0)

id_box=Entry(add_frame)
id_box.grid(row=1,column=1)

topping_box=Entry(add_frame)
topping_box.grid(row=1,column=2)


Button(r,text="Add",command=add_record).pack(pady=20)

connection.commit() 
connection.close()

r.mainloop()

# %%
from tkinter import *
from tkinter import ttk
r=Tk()
r.geometry('500x600')

my_tree=ttk.Treeview(r)

#Define Our Columns
my_tree['columns']=("Name","ID","Favorite Pizza")

#Format Our Columns
my_tree.column("#0",width=0,stretch=NO)
my_tree.column("Name",anchor=W,width=140)
my_tree.column("ID",anchor=CENTER,width=100)
my_tree.column("Favorite Pizza",anchor=W,width=140)

#Create Headings
my_tree.heading("#0",text="",anchor=W)
my_tree.heading("Name",text="Name",anchor=W)
my_tree.heading("ID",text="ID",anchor=CENTER)
my_tree.heading("Favorite Pizza",text="Favorite Pizza",anchor=W)

#Add Data
data=[["Jhon",1,"Peperroni Pizza"],
       ["Mas",2,"cheese Pizza"],
        ["Sed",3,"der Pizza"],
        ["Ali",4,"Ham Pizza"],
        ["Hoza",5,"deli Pizza"],
        ["Nor",6,"aprg Pizza"]
      ]

global count
count=0
for record in data:
    my_tree.insert(parent='',index='end',iid=count,text="",values=(record[0],record[1],record[2]))
    count+=1

#Pack to the Screen
my_tree.pack(pady=20)

add_frame=Frame(r)
add_frame.pack(pady=20)

#Labels
nl=Label(add_frame,text="Name")
nl.grid(row=0,column=0)

il=Label(add_frame,text="ID")
il.grid(row=0,column=1)

tl=Label(add_frame,text="Topping")
tl.grid(row=0,column=2)

#Entry boxes
name_box=Entry(add_frame)
name_box.grid(row=1,column=0)

id_box=Entry(add_frame)
id_box.grid(row=1,column=1)

topping_box=Entry(add_frame)
topping_box.grid(row=1,column=2)

#Add Record
def add_record():
    global count
    my_tree.insert(parent='',index='end',iid=count,text="",values=(name_box.get(),id_box.get(),topping_box.get()))
    count+=1
    
    #Clear the Boxes
    name_box.delete(0,END)
    id_box.delete(0,END)
    topping_box.delete(0,END)
    
#Remove All Records
def remove_all():
    for record in my_tree.get_children():
        my_tree.delete(record)

#Remove the selected one
def remove_one():
    x=my_tree.selection()[0]  #my_tree.selection()[0] for select one item only
    my_tree.delete(x)
    
#Remove many selected 
def remove_many():
    x=my_tree.selection()
    for record in x:
        my_tree.delete(record)

#Buttons
add_records=Button(r,text="Add Record",command=add_record)
add_records.pack(pady=20)

#Remove all
remove_all=Button(r,text="Remove All Records",command=remove_all)
remove_all.pack(pady=10)

#Remove the selected one
remove_one=Button(r,text="Remove One Selected",command=remove_one)
remove_one.pack(pady=10)

#Remove many selected 
remove_many=Button(r,text="Remove Many Selected",command=remove_many)
remove_many.pack(pady=10)

r.mainloop()

# %%
from tkinter import *
from tkinter import ttk
r=Tk()
r.geometry('500x600')

#Add Some Style
style=ttk.Style()
#Pick a theme
style.theme_use("default") #default,clam,alt

#Configre our treeview colors
style.configure("Treeview",
                background="#D3D3D3",
                forground="black",
                rowheight=25,
                fieldbackground="#D3D3D3"
               )

#Change Selected Color
style.map("Treeview",
         background=[('selected','blue')])

my_tree=ttk.Treeview(r)

#Define Our Columns
my_tree['columns']=("Name","ID","Favorite Pizza")

#Format Our Columns
my_tree.column("#0",width=0,stretch=NO)
my_tree.column("Name",anchor=W,width=140)
my_tree.column("ID",anchor=CENTER,width=100)
my_tree.column("Favorite Pizza",anchor=W,width=140)

#Create Headings
my_tree.heading("#0",text="",anchor=W)
my_tree.heading("Name",text="Name",anchor=W)
my_tree.heading("ID",text="ID",anchor=CENTER)
my_tree.heading("Favorite Pizza",text="Favorite Pizza",anchor=W)

#Add Data
data=[["Jhon",1,"Peperroni Pizza"],
       ["Mas",2,"cheese Pizza"],
        ["Sed",3,"der Pizza"],
        ["Ali",4,"Ham Pizza"],
        ["Hoza",5,"deli Pizza"],
        ["Nor",6,"aprg Pizza"]
      ]

global count
count=0
for record in data:
    my_tree.insert(parent='',index='end',iid=count,text="",values=(record[0],record[1],record[2]))
    count+=1

#Pack to the Screen
my_tree.pack(pady=20)

add_frame=Frame(r)
add_frame.pack(pady=20)

#Labels
nl=Label(add_frame,text="Name")
nl.grid(row=0,column=0)

il=Label(add_frame,text="ID")
il.grid(row=0,column=1)

tl=Label(add_frame,text="Topping")
tl.grid(row=0,column=2)

#Entry boxes
name_box=Entry(add_frame)
name_box.grid(row=1,column=0)

id_box=Entry(add_frame)
id_box.grid(row=1,column=1)

topping_box=Entry(add_frame)
topping_box.grid(row=1,column=2)

#Add Record
def add_record():
    global count
    my_tree.insert(parent='',index='end',iid=count,text="",values=(name_box.get(),id_box.get(),topping_box.get()))
    count+=1
    
    #Clear the Boxes
    name_box.delete(0,END)
    id_box.delete(0,END)
    topping_box.delete(0,END)
    
#Remove All Records
def remove_all():
    for record in my_tree.get_children():
        my_tree.delete(record)

#Remove the selected one
def remove_one():
    x=my_tree.selection()[0]  #my_tree.selection()[0] for select one item only
    my_tree.delete(x)
    
#Remove many selected 
def remove_many():
    x=my_tree.selection()
    for record in x:
        my_tree.delete(record)

#Buttons
add_records=Button(r,text="Add Record",command=add_record)
add_records.pack(pady=20)

#Remove all
remove_all=Button(r,text="Remove All Records",command=remove_all)
remove_all.pack(pady=10)

#Remove the selected one
remove_one=Button(r,text="Remove One Selected",command=remove_one)
remove_one.pack(pady=10)

#Remove many selected 
remove_many=Button(r,text="Remove Many Selected",command=remove_many)
remove_many.pack(pady=10)

r.mainloop()

# %%
from tkinter import *
from tkinter import ttk
r=Tk()
r.geometry('500x600')

#Add Some Style
style=ttk.Style()
#Pick a theme
style.theme_use("default") #default,clam,alt

#Configre our treeview colors
style.configure("Treeview",
                background="white",
                forground="black",
                rowheight=25,
                fieldbackground="white"
               )

#Change Selected Color
style.map("Treeview",
         background=[('selected','blue')])

my_tree=ttk.Treeview(r)

#Define Our Columns
my_tree['columns']=("Name","ID","Favorite Pizza")

#Format Our Columns
my_tree.column("#0",width=0,stretch=NO)
my_tree.column("Name",anchor=W,width=140)
my_tree.column("ID",anchor=CENTER,width=100)
my_tree.column("Favorite Pizza",anchor=W,width=140)

#Create Headings
my_tree.heading("#0",text="",anchor=W)
my_tree.heading("Name",text="Name",anchor=W)
my_tree.heading("ID",text="ID",anchor=CENTER)
my_tree.heading("Favorite Pizza",text="Favorite Pizza",anchor=W)

#Add Data
data=[["Jhon",1,"Peperroni Pizza"],
       ["Mas",2,"cheese Pizza"],
        ["Sed",3,"der Pizza"],
        ["Ali",4,"Ham Pizza"],
        ["Hoza",5,"deli Pizza"],
        ["Nor",6,"aprg Pizza"],
      ["stev",7,"superem"],
      ["Tina",8,"olsdsd"],
      ["Ruth",9,"Vegan"]
      ]

#Create striped row tags
my_tree.tag_configure('oddRow',background="white")
my_tree.tag_configure('evenRow',background="lightblue")

global count
count=0
for record in data:
    if count%2==0:
        my_tree.insert(parent='',index='end',iid=count,text="",
                       values=(record[0],record[1],record[2]),tags=('evenRow'))
    else:
        my_tree.insert(parent='',index='end',iid=count,text="",
                       values=(record[0],record[1],record[2]),tags=('oddRow'))
        
    count+=1

#Pack to the Screen
my_tree.pack(pady=20)

add_frame=Frame(r)
add_frame.pack(pady=20)

#Labels
nl=Label(add_frame,text="Name")
nl.grid(row=0,column=0)

il=Label(add_frame,text="ID")
il.grid(row=0,column=1)

tl=Label(add_frame,text="Topping")
tl.grid(row=0,column=2)

#Entry boxes
name_box=Entry(add_frame)
name_box.grid(row=1,column=0)

id_box=Entry(add_frame)
id_box.grid(row=1,column=1)

topping_box=Entry(add_frame)
topping_box.grid(row=1,column=2)

#Add Record
def add_record():
    my_tree.tag_configure('oddRow',background="white")
    my_tree.tag_configure('evenRow',background="lightblue")
    global count
    if count%2==0:
        my_tree.insert(parent='',index='end',iid=count,text="",
                       values=(name_box.get(),id_box.get(),topping_box.get()),tags=('evenRow'))
    else:
        my_tree.insert(parent='',index='end',iid=count,text="",
                       values=(name_box.get(),id_box.get(),topping_box.get()),tags=('oddRow'))
        
    count+=1
    
    #Clear the Boxes
    name_box.delete(0,END)
    id_box.delete(0,END)
    topping_box.delete(0,END)
    
#Remove All Records
def remove_all():
    for record in my_tree.get_children():
        my_tree.delete(record)

#Remove the selected one
def remove_one():
    x=my_tree.selection()[0]  #my_tree.selection()[0] for select one item only
    my_tree.delete(x)
    
#Remove many selected 
def remove_many():
    x=my_tree.selection()
    for record in x:
        my_tree.delete(record)

#Buttons
add_records=Button(r,text="Add Record",command=add_record)
add_records.pack(pady=20)

#Remove all
remove_all=Button(r,text="Remove All Records",command=remove_all)
remove_all.pack(pady=10)

#Remove the selected one
remove_one=Button(r,text="Remove One Selected",command=remove_one)
remove_one.pack(pady=10)

#Remove many selected 
remove_many=Button(r,text="Remove Many Selected",command=remove_many)
remove_many.pack(pady=10)

r.mainloop()

# %%
#Adding Scrollbar

# %%
from tkinter import *
from tkinter import ttk
r=Tk()
r.geometry('500x600')

#Add Some Style
style=ttk.Style()
#Pick a theme
style.theme_use("default") #default,clam,alt

#Configre our treeview colors
style.configure("Treeview",
                background="white",
                forground="black",
                rowheight=25,
                fieldbackground="white"
               )

#Change Selected Color
style.map("Treeview",
         background=[('selected','blue')])

#Create treeview Frame
tree_frame=Frame(r)
tree_frame.pack(pady=20)

#Treeview Scrollbar
tree_scroll=Scrollbar(tree_frame)
tree_scroll.pack(side="right",fill=Y)

#Create Treeview
my_tree=ttk.Treeview(tree_frame, yscrollcommand=tree_scroll.set)
#pack to the screen
my_tree.pack()

#Configure the scrollbar
tree_scroll.config(command=my_tree.yview)

#Define Our Columns
my_tree['columns']=("Name","ID","Favorite Pizza")

#Format Our Columns
my_tree.column("#0",width=0,stretch=NO)
my_tree.column("Name",anchor=W,width=140)
my_tree.column("ID",anchor=CENTER,width=100)
my_tree.column("Favorite Pizza",anchor=W,width=140)

#Create Headings
my_tree.heading("#0",text="",anchor=W)
my_tree.heading("Name",text="Name",anchor=W)
my_tree.heading("ID",text="ID",anchor=CENTER)
my_tree.heading("Favorite Pizza",text="Favorite Pizza",anchor=W)

#Add Data
data=[["Jhon",1,"Peperroni Pizza"],
       ["Mas",2,"cheese Pizza"],
        ["Sed",3,"der Pizza"],
        ["Ali",4,"Ham Pizza"],
        ["Hoza",5,"deli Pizza"],
        ["Nor",6,"aprg Pizza"],
      ["stev",7,"superem"],
      ["Tina",8,"olsdsd"],
      ["Ruth",9,"Vegan"],
      ["Jhon",1,"Peperroni Pizza"],
       ["Mas",2,"cheese Pizza"],
        ["Sed",3,"der Pizza"],
        ["Ali",4,"Ham Pizza"],
        ["Hoza",5,"deli Pizza"],
        ["Nor",6,"aprg Pizza"],
      ["stev",7,"superem"],
      ["Tina",8,"olsdsd"],
      ["Ruth",9,"Vegan"]
      ]

#Create striped row tags
my_tree.tag_configure('oddRow',background="white")
my_tree.tag_configure('evenRow',background="lightblue")

global count
count=0
for record in data:
    if count%2==0:
        my_tree.insert(parent='',index='end',iid=count,text="",
                       values=(record[0],record[1],record[2]),tags=('evenRow'))
    else:
        my_tree.insert(parent='',index='end',iid=count,text="",
                       values=(record[0],record[1],record[2]),tags=('oddRow'))
        
    count+=1



add_frame=Frame(r)
add_frame.pack(pady=20)

#Labels
nl=Label(add_frame,text="Name")
nl.grid(row=0,column=0)

il=Label(add_frame,text="ID")
il.grid(row=0,column=1)

tl=Label(add_frame,text="Topping")
tl.grid(row=0,column=2)

#Entry boxes
name_box=Entry(add_frame)
name_box.grid(row=1,column=0)

id_box=Entry(add_frame)
id_box.grid(row=1,column=1)

topping_box=Entry(add_frame)
topping_box.grid(row=1,column=2)

#Add Record
def add_record():
    my_tree.tag_configure('oddRow',background="white")
    my_tree.tag_configure('evenRow',background="lightblue")
    global count
    if count%2==0:
        my_tree.insert(parent='',index='end',iid=count,text="",
                       values=(name_box.get(),id_box.get(),topping_box.get()),tags=('evenRow'))
    else:
        my_tree.insert(parent='',index='end',iid=count,text="",
                       values=(name_box.get(),id_box.get(),topping_box.get()),tags=('oddRow'))
        
    count+=1
    
    #Clear the Boxes
    name_box.delete(0,END)
    id_box.delete(0,END)
    topping_box.delete(0,END)
    
#Remove All Records
def remove_all():
    for record in my_tree.get_children():
        my_tree.delete(record)

#Remove the selected one
def remove_one():
    x=my_tree.selection()[0]  #my_tree.selection()[0] for select one item only
    my_tree.delete(x)
    
#Remove many selected 
def remove_many():
    x=my_tree.selection()
    for record in x:
        my_tree.delete(record)

#Buttons
add_records=Button(r,text="Add Record",command=add_record)
add_records.pack(pady=20)

#Remove all
remove_all=Button(r,text="Remove All Records",command=remove_all)
remove_all.pack(pady=10)

#Remove the selected one
remove_one=Button(r,text="Remove One Selected",command=remove_one)
remove_one.pack(pady=10)

#Remove many selected 
remove_many=Button(r,text="Remove Many Selected",command=remove_many)
remove_many.pack(pady=10)

r.mainloop()

# %%
#Update the records

# %%
from tkinter import *
from tkinter import ttk
r=Tk()
r.geometry('600x700+0+0')

#Add Some Style
style=ttk.Style()
#Pick a theme
style.theme_use("default") #default,clam,alt

#Configre our treeview colors
style.configure("Treeview",
                background="white",
                forground="black",
                rowheight=25,
                fieldbackground="white"
               )

#Change Selected Color
style.map("Treeview",
         background=[('selected','blue')])

#Create treeview Frame
tree_frame=Frame(r)
tree_frame.pack(pady=20)

#Treeview Scrollbar
tree_scroll=Scrollbar(tree_frame)
tree_scroll.pack(side="right",fill=Y)

#Create Treeview
my_tree=ttk.Treeview(tree_frame, yscrollcommand=tree_scroll.set)
#pack to the screen
my_tree.pack()

#Configure the scrollbar
tree_scroll.config(command=my_tree.yview)

#Define Our Columns
my_tree['columns']=("Name","ID","Favorite Pizza")

#Format Our Columns
my_tree.column("#0",width=0,stretch=NO)
my_tree.column("Name",anchor=W,width=140)
my_tree.column("ID",anchor=CENTER,width=100)
my_tree.column("Favorite Pizza",anchor=W,width=140)

#Create Headings
my_tree.heading("#0",text="",anchor=W)
my_tree.heading("Name",text="Name",anchor=W)
my_tree.heading("ID",text="ID",anchor=CENTER)
my_tree.heading("Favorite Pizza",text="Favorite Pizza",anchor=W)

#Add Data
data=[["Jhon",1,"Peperroni Pizza"],
       ["Mas",2,"cheese Pizza"],
        ["Sed",3,"der Pizza"],
        ["Ali",4,"Ham Pizza"],
        ["Hoza",5,"deli Pizza"],
        ["Nor",6,"aprg Pizza"],
      ["stev",7,"superem"],
      ["Tina",8,"olsdsd"],
      ["Ruth",9,"Vegan"],
      ["Jhon",1,"Peperroni Pizza"],
       ["Mas",2,"cheese Pizza"],
        ["Sed",3,"der Pizza"],
        ["Ali",4,"Ham Pizza"],
        ["Hoza",5,"deli Pizza"],
        ["Nor",6,"aprg Pizza"],
      ["stev",7,"superem"],
      ["Tina",8,"olsdsd"],
      ["Ruth",9,"Vegan"]
      ]

#Create striped row tags
my_tree.tag_configure('oddRow',background="white")
my_tree.tag_configure('evenRow',background="lightblue")

global count
count=0
for record in data:
    if count%2==0:
        my_tree.insert(parent='',index='end',iid=count,text="",
                       values=(record[0],record[1],record[2]),tags=('evenRow'))
    else:
        my_tree.insert(parent='',index='end',iid=count,text="",
                       values=(record[0],record[1],record[2]),tags=('oddRow'))
        
    count+=1



add_frame=Frame(r)
add_frame.pack(pady=20)

#Labels
nl=Label(add_frame,text="Name")
nl.grid(row=0,column=0)

il=Label(add_frame,text="ID")
il.grid(row=0,column=1)

tl=Label(add_frame,text="Topping")
tl.grid(row=0,column=2)

#Entry boxes
name_box=Entry(add_frame)
name_box.grid(row=1,column=0)

id_box=Entry(add_frame)
id_box.grid(row=1,column=1)

topping_box=Entry(add_frame)
topping_box.grid(row=1,column=2)

#Add Record
def add_record():
    my_tree.tag_configure('oddRow',background="white")
    my_tree.tag_configure('evenRow',background="lightblue")
    global count
    if count%2==0:
        my_tree.insert(parent='',index='end',iid=count,text="",
                       values=(name_box.get(),id_box.get(),topping_box.get()),tags=('evenRow'))
    else:
        my_tree.insert(parent='',index='end',iid=count,text="",
                       values=(name_box.get(),id_box.get(),topping_box.get()),tags=('oddRow'))
        
    count+=1
    
    #Clear the Boxes
    name_box.delete(0,END)
    id_box.delete(0,END)
    topping_box.delete(0,END)
    
#Remove All Records
def remove_all():
    for record in my_tree.get_children():
        my_tree.delete(record)

#Remove the selected one
def remove_one():
    x=my_tree.selection()[0]  #my_tree.selection()[0] for select one item only
    my_tree.delete(x)
    
#Remove many selected 
def remove_many():
    x=my_tree.selection()
    for record in x:
        my_tree.delete(record)
        
#Select Record
def select_record():
    #Cleare Entry Boxes
    name_box.delete(0,END)
    id_box.delete(0,END)
    topping_box.delete(0,END)
    
    #grab record number
    selected=my_tree.focus()
    #grab record values
    values=my_tree.item(selected,'values')
    
    #temp_label.config(text=values[0])  #Return Tuple
    
    #Output to entry boxes
    name_box.insert(0,values[0])
    id_box.insert(0,values[1])
    topping_box.insert(0,values[2])

#Save Update Record
def update_record():
    #grab record number
    selected=my_tree.focus()
    #save new data
    my_tree.item(selected,text="", values=(name_box.get(),id_box.get(),topping_box.get()))
    
    #Cleare Entry Boxes
    name_box.delete(0,END)
    id_box.delete(0,END)
    topping_box.delete(0,END)

#Buttons
select_button=Button(r,text="Select Record",command=select_record)
select_button.pack(pady=5)

update_button=Button(r,text="Save Record",command=update_record)
update_button.pack(pady=5)

add_records=Button(r,text="Add Record",command=add_record)
add_records.pack(pady=5)

#Remove all
remove_all=Button(r,text="Remove All Records",command=remove_all)
remove_all.pack(pady=5)

#Remove the selected one
remove_one=Button(r,text="Remove One Selected",command=remove_one)
remove_one.pack(pady=5)

#Remove many selected 
remove_many=Button(r,text="Remove Many Selected",command=remove_many)
remove_many.pack(pady=5)

temp_label=Label(r,text="")
temp_label.pack(pady=5)

r.mainloop()
