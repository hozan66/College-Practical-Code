# %%
BMI=1
x=0
def st():
    global x
    x=x+1
    boint.set(f'{x}')
    a.set("Height in inches ")
    bb.set("Weight in IBS")
def f():
    a.set("Height in CM")
    bb.set('weight in KG')
def e():
    vcc.config(bg="yellow")
    global BMI
    BMI=(float(w.get())/((float(h.get())/100)**2))
    
    hh=float(h.get())/100
    ww=float(w.get())/100
    
    cv.set(f'BMI you = {BMI}')
    
    if BMI<18.5:
        vc.set("UnderWeight")     
    if BMI>=18.5 and BMI<=24.9:
        vc.set("NormalRange") 
    if BMI>=25.0 and BMI<=29.9:
        vc.set("Over Weight")   
    if BMI>=30:
        vc.set("Obese")
        
    minWight =18.5 *hh*hh
    b=round(minWight)
    maxWight=25  *hh*hh 
    newWeight = 0000.0000
    
    if BMI<18.5 :
        newWeight = ww + (b - ww) * 2
        newWeight=newWeight/2
        a=round(newWeight)
        anjameKotay.set(f'pewesta waznt zyad bkay bo [{a}] KG' )
    elif BMI>24.5:
        newWeight = ww + (maxWight - ww) * 2
        newWeight=newWeight/2
        a=round(newWeight)
        anjameKotay.set(f'pewesta waznt kam bkay bo [{a}] KG' )
    else:
        anjameKotay.set(f'kesht tandrusra' )
    
from tkinter import*
r=Tk()
r.geometry('500x500')
r.title('login')
r.configure(bg='green')

boint=(f'{x}' ) 

if int(boint)%2==1:
    butnn=StringVar()
    butnn.set('Standard')
    butn=Button(r,textvariable=butnn,command=st)
    butn.config(font=('arial',24))
    butn.pack()
    
if int(boint)%2==0:
    butnn=StringVar()
    butnn.set('METRIC')
    butn=Button(r,textvariable=butnn,command=f)
    butn.config(font=('arial',24))
    butn.pack()

    
a=StringVar()
a.set("Height")
l=Label(r,textvariable=a)
l.config(bg="pink",font=('arial',24))
l.pack()

en=StringVar()
en.set("")
h=Entry(r,textvariable=en)
h.config(font=('arial',24))
h.pack()

bb=StringVar()
bb.set('weight')
b=Label(r,textvariable=bb)
b.config(bg="pink",font=('arial',24))
b.pack()

enn=StringVar()
enn.set("")
w=Entry(r,textvariable=enn)
w.config(font=('arial',24))
w.pack()

butn=StringVar()
butn.set('Calculate')
butn=Button(r,textvariable=butn,command=e)
butn.config(font=('arial',24))
butn.pack()
cv=StringVar()
cv.set("")
cc=Label(r,textvariable=cv)
cc.config(bg="green",font=('arial',24))
cc.pack()
vc=StringVar()
vc.set("")
vcc=Label(r,textvariable=vc)
vcc.config(bg="green",font=('arial',24))
vcc.pack()


anjameKotay=StringVar()
anjameKotay.set("")
anjam=Label(r,textvariable=anjameKotay)
anjam.config(bg="green",font=('arial',24))
anjam.pack()

    

r.mainloop()
